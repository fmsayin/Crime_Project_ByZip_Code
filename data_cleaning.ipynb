# %%
# !ls
# Out:
# ACS_16_5YR_S1501 - Educational Attainment
# AK Austin crime cleanup.ipynb
# Crime_Reports_2017.csv
# data_cleaning.ipynb
# educational_attainment.csv
# Poverty.csv
# Poverty_read.ipynb
# README.md
# test.txt
# unemployment rate, household income, poverty rate
# Untitled.ipynb
# Untitled1.ipynb

# %%
import pandas as pd

# %%
path="educational_attainment.csv"

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#            GEO.id GEO.id2 GEO.display-label  \
# 0              Id     Id2         Geography
# 1  8600000US78610   78610       ZCTA5 78610
# 2  8600000US78613   78613       ZCTA5 78613
# 3  8600000US78617   78617       ZCTA5 78617
# 4  8600000US78641   78641       ZCTA5 78641
#
#                                 HC01_EST_VC02  \
# 0  Total; Estimate; Population 18 to 24 years
# 1                                        2625
# 2                                        5125
# 3                                        3103
# 4                                        3467
#
#                                        HC01_MOE_VC02  \
# 0  Total; Margin of Error; Population 18 to 24 years
# 1                                                638
# 2                                                625
# 3                                                525
# 4                                                557
#
#                                   HC02_EST_VC02  \
# ...

# %%
df.columns = df.iloc[0]

# %%
df.head()
# Out:
# 0              Id    Id2    Geography  \
# 0              Id    Id2    Geography
# 1  8600000US78610  78610  ZCTA5 78610
# 2  8600000US78613  78613  ZCTA5 78613
# 3  8600000US78617  78617  ZCTA5 78617
# 4  8600000US78641  78641  ZCTA5 78641
#
# 0  Total; Estimate; Population 18 to 24 years  \
# 0  Total; Estimate; Population 18 to 24 years
# 1                                        2625
# 2                                        5125
# 3                                        3103
# 4                                        3467
#
# 0  Total; Margin of Error; Population 18 to 24 years  \
# 0  Total; Margin of Error; Population 18 to 24 years
# 1                                                638
# 2                                                625
# 3                                                525
# 4                                                557
#
# 0  Percent; Estimate; Population 18 to 24 years  \
# 0  Percent; Estimate; Population 18 to 24 years
# ...

# %%
df=df.drop(df.index[0])

# %%
df.head()
# Out:
# 0              Id    Id2    Geography  \
# 1  8600000US78610  78610  ZCTA5 78610
# 2  8600000US78613  78613  ZCTA5 78613
# 3  8600000US78617  78617  ZCTA5 78617
# 4  8600000US78641  78641  ZCTA5 78641
# 5  8600000US78652  78652  ZCTA5 78652
#
# 0 Total; Estimate; Population 18 to 24 years  \
# 1                                       2625
# 2                                       5125
# 3                                       3103
# 4                                       3467
# 5                                        313
#
# 0 Total; Margin of Error; Population 18 to 24 years  \
# 1                                               638
# 2                                               625
# 3                                               525
# 4                                               557
# 5                                               161
#
# 0 Percent; Estimate; Population 18 to 24 years  \
# 1                                          (X)
# ...

# %%
list(df)
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'Total; Estimate; Population 18 to 24 years',
#  'Total; Margin of Error; Population 18 to 24 years',
#  'Percent; Estimate; Population 18 to 24 years',
#  'Percent; Margin of Error; Population 18 to 24 years',
#  'Males; Estimate; Population 18 to 24 years',
#  'Males; Margin of Error; Population 18 to 24 years',
#  'Percent Males; Estimate; Population 18 to 24 years',
#  'Percent Males; Margin of Error; Population 18 to 24 years',
#  'Females; Estimate; Population 18 to 24 years',
#  'Females; Margin of Error; Population 18 to 24 years',
#  'Percent Females; Estimate; Population 18 to 24 years',
#  'Percent Females; Margin of Error; Population 18 to 24 years',
#  'Total; Estimate; Population 18 to 24 years - Less than high school graduate',
#  'Total; Margin of Error; Population 18 to 24 years - Less than high school graduate',
#  'Percent; Estimate; Population 18 to 24 years - Less than high school graduate',
# ...

# %%
df_new = df[['Geography',
             'Total; Estimate; Population 18 to 24 years', 
             'Total; Margin of Error; Population 18 to 24 years - Less than high school graduate', 
             'Percent Males; Margin of Error; Population 18 to 24 years - High school graduate (includes equivalency)',
              "Males; Margin of Error; Population 18 to 24 years - Some college or associate's degree",
              "Total; Estimate; Population 18 to 24 years - Bachelor's degree or higher",
              'Percent; Estimate; Population 25 years and over - Less than 9th grade']]

# %%
df_new
# Out:
# 0     Geography Total; Estimate; Population 18 to 24 years  \
# 1   ZCTA5 78610                                       2625
# 2   ZCTA5 78613                                       5125
# 3   ZCTA5 78617                                       3103
# 4   ZCTA5 78641                                       3467
# 5   ZCTA5 78652                                        313
# 6   ZCTA5 78653                                       1445
# 7   ZCTA5 78660                                       5824
# 8   ZCTA5 78664                                       5656
# 9   ZCTA5 78681                                       3914
# 10  ZCTA5 78701                                        528
# 11  ZCTA5 78702                                       1759
# 12  ZCTA5 78703                                        915
# 13  ZCTA5 78704                                       4750
# 14  ZCTA5 78705                                      24954
# 15  ZCTA5 78712                                        838
# ...

# %%
len(df_new.columns)
# Out:
# 7

# %%
df_new.columns = ['a1', 'b1','c1','d1','e1','f1','g1']

# %%
df_new.head()
# Out:
#             a1    b1   c1    d1   e1   f1    g1
# 1  ZCTA5 78610  2625  203  14.9  241   74   5.6
# 2  ZCTA5 78613  5125  193  10.1  324  485   1.3
# 3  ZCTA5 78617  3103  344   8.7  170  175  19.3
# 4  ZCTA5 78641  3467  158   9.1  261  241   3.9
# 5  ZCTA5 78652   313   43  16.4   49  100   4.8

# %%
df_new.to_csv('education_clean.csv')
