# %%
import pandas as pd

import numpy as np

# %%
crime_load = "Crime_Reports_2016.csv"
crime_df = pd.read_csv(crime_load)
crime_df.head()
# Out:
#    Incident Number   Highest Offense Description  Highest Offense Code  \
# 0     2.016520e+09                           DWI                  2100
# 1     2.016242e+10  DRIVING WHILE INTOX / FELONY                  2109
# 2     2.016298e+10                           DWI                  2100
# 3     2.016501e+10                 FRAUD - OTHER                  1199
# 4     2.016780e+09           DISTURBANCE - OTHER                  3401
#
#   Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 0               N       2/21/16 2:12       2/21/16            212
# 1               N       8/29/16 0:16       8/29/16             16
# 2               N     10/24/16 21:31      10/24/16           2131
# 3               N       3/2/16 14:55        3/2/16           1455
# 4               N       3/18/16 3:37       3/18/16            337
#
#   Report Date Time Report Date  Report Time             ...               \
# 0     2/21/16 2:12     2/21/16          212             ...
# ...

# %%
crime_df.columns
# Out:
# Index(['Incident Number', 'Highest Offense Description',
#        'Highest Offense Code', 'Family Violence', 'Occurred Date Time',
#        'Occurred Date', 'Occurred Time', 'Report Date Time', 'Report Date',
#        'Report Time', 'Location Type', 'Address', 'Zip Code',
#        'Council District', 'APD Sector', 'APD District', 'PRA', 'Census Tract',
#        'Clearance Status', 'Clearance Date', 'UCR Category',
#        'Category Description', 'X-coordinate', 'Y-coordinate', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
#check data types
crime_df.dtypes
# Out:
# Incident Number                float64
# Highest Offense Description     object
# Highest Offense Code             int64
# Family Violence                 object
# Occurred Date Time              object
# Occurred Date                   object
# Occurred Time                    int64
# Report Date Time                object
# Report Date                     object
# Report Time                      int64
# Location Type                   object
# Address                         object
# Zip Code                         int64
# Council District               float64
# APD Sector                      object
# APD District                    object
# PRA                              int64
# Census Tract                   float64
# Clearance Status                object
# Clearance Date                  object
# UCR Category                    object
# Category Description            object
# X-coordinate                     int64
# Y-coordinate                     int64
# ...

# %%
#find number of zip codes. Bad values and periods after zips need to be removed
unique_zip = crime_df["Zip Code"].unique()
unique_zip
# Out:
# array([78753, 78704, 78701, 78741, 78756, 78758, 78745, 78721, 78751,
#        78702, 78744, 78731, 78705, 78750, 78723, 78727, 78703, 78752,
#        78735, 78749, 78746, 78757, 78759, 78722, 78730, 78742, 78712,
#        78732, 78733])

# %%
#checking number of incidents in each zip. NOte: all zip codes are within Austin City limits

crime_df["Zip Code"].value_counts()
# Out:
# 78741    9944
# 78753    8847
# 78701    8096
# 78758    8084
# 78704    7378
# 78745    7093
# 78744    6566
# 78723    6157
# 78702    5454
# 78752    3614
# 78751    3011
# 78759    2970
# 78705    2580
# 78757    2552
# 78721    2158
# 78749    2047
# 78703    1776
# 78727    1626
# 78746    1618
# 78731    1275
# 78750    1234
# 78735     832
# 78722     813
# 78756     813
# 78742     172
# 78730     149
# 78733      26
# 78712      22
# 78732      12
# Name: Zip Code, dtype: int64

# %%
#check row value counts. 113217 is complete amount of row data, but some columns we can drop b/c they'll be unnecessary 
#(like APD District?) But there are some missing zip codes that should be filled in, and also some missing latititude & longitude.

crime_df.count()
# Out:
# Incident Number                96919
# Highest Offense Description    96919
# Highest Offense Code           96919
# Family Violence                96919
# Occurred Date Time             96919
# Occurred Date                  96919
# Occurred Time                  96919
# Report Date Time               96919
# Report Date                    96919
# Report Time                    96919
# Location Type                  96339
# Address                        96919
# Zip Code                       96919
# Council District               96801
# APD Sector                     96919
# APD District                   96919
# PRA                            96919
# Census Tract                   96919
# Clearance Status               87421
# Clearance Date                 87421
# UCR Category                   32060
# Category Description           32060
# X-coordinate                   96919
# Y-coordinate                   96919
# Latitude                       95540
# ...

# %%
#dropping columns that we don't need: commented out after deletions were made
del crime_df["Occurred Date Time"]
del crime_df["Occurred Date"]
del crime_df["Occurred Time"]
del crime_df["Report Date Time"]
del crime_df["Report Date"]
del crime_df["Report Time"]
del crime_df["Address"]
del crime_df["Council District"]
del crime_df["APD Sector"]
del crime_df["APD District"]
del crime_df["PRA"]
del crime_df["Census Tract"]
del crime_df["Clearance Status"]
del crime_df["Clearance Date"]
del crime_df["UCR Category"]
del crime_df["Category Description"]
del crime_df["X-coordinate"]
del crime_df["Y-coordinate"]

#show clean table
crime_df.head()
# Out:
#    Incident Number   Highest Offense Description  Highest Offense Code  \
# 0     2.016520e+09                           DWI                  2100
# 1     2.016242e+10  DRIVING WHILE INTOX / FELONY                  2109
# 2     2.016298e+10                           DWI                  2100
# 3     2.016501e+10                 FRAUD - OTHER                  1199
# 4     2.016780e+09           DISTURBANCE - OTHER                  3401
#
#   Family Violence                 Location Type  Zip Code   Latitude  \
# 0               N  STREETS / HWY / ROAD / ALLEY     78753  30.370293
# 1               N  STREETS / HWY / ROAD / ALLEY     78704  30.228455
# 2               N  STREETS / HWY / ROAD / ALLEY     78701  30.264593
# 3               N              RESIDENCE / HOME     78701  30.280296
# 4               N  STREETS / HWY / ROAD / ALLEY     78701  30.267351
#
#    Longitude                     Location
# 0 -97.683877  (30.37029315, -97.68387677)
# ...

# %%
#remove blanks from zip code & other fields
crime_df=crime_df.dropna(how='any')
#verify counts
crime_df.count()
# Out:
# Incident Number                94974
# Highest Offense Description    94974
# Highest Offense Code           94974
# Family Violence                94974
# Location Type                  94974
# Zip Code                       94974
# Latitude                       94974
# Longitude                      94974
# Location                       94974
# dtype: int64

# %%
#checking offense types: there are 269 total. 
crime_type_count = crime_df["Highest Offense Description"].value_counts()
crime_type_count
# Out:
# THEFT                             8934
# FAMILY DISTURBANCE                8819
# BURGLARY OF VEHICLE               7298
# CRIMINAL MISCHIEF                 5017
# DISTURBANCE - OTHER               3206
# DWI                               3049
# ASSAULT W/INJURY-FAM/DATE VIOL    2848
# THEFT BY SHOPLIFTING              2781
# BURGLARY OF RESIDENCE             2721
# WARRANT ARREST NON TRAFFIC        2155
# ASSAULT WITH INJURY               2137
# PUBLIC INTOXICATION               2051
# POSS MARIJUANA                    2043
# RUNAWAY CHILD                     1969
# HARASSMENT                        1910
# AUTO THEFT                        1722
# ASSAULT BY CONTACT                1689
# POSS CONTROLLED SUB/NARCOTIC      1666
# CUSTODY ARREST TRAFFIC WARR       1499
# BURGLARY NON RESIDENCE            1405
# THEFT OF BICYCLE                  1339
# FRAUD - OTHER                     1196
# IDENTITY THEFT                    1136
# CRIMINAL TRESPASS                 1050
# ...

# %%
#converting specific offenses into crime types 
crime_cons = crime_df
#property crime group
crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({

crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({"PUBLIC INTOXICATION":"drug/alcohol", 
                                            "POSS MARIJUANA":"drug/alcohol","POSS CONTROLLED SUB/NARCOTIC":"drug/alcohol","POSS OF DRUG PARAPHERNALIA":"drug/alcohol",
                                            "POSS SYNTHETIC MARIJUANA":"drug/alcohol", "DEL CONTROLLED SUB/NARCOTIC":"drug/alcohol", "POSS CONTROLLED SUB/SYN NARC":"drug/alcohol",
                                            "POSS CONTROLLED SUB/OTHER":"drug/alcohol","VOCO - ALCOHOL  CONSUMPTION":"drug/alcohol","LIQUOR LAW VIOLATION/OTHER":"drug/alcohol",
                                            "POSS DANG DRUG":"drug/alcohol","POSS OF ALCOHOL - AGE 17 TO 20":"drug/alcohol","OBTAIN CONTROLLED SUB BY FRAUD":"drug/alcohol",
                                             "DEL CONTROLLED SUB/SYN NARC":"drug/alcohol","DEL SYNTHETIC MARIJUANA":"drug/alcohol","INHALANT ABUSE":"drug/alcohol"})
#statutory group
crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({"WARRANT ARREST NON TRAFFIC":"statutory",
                                            "VIOL CITY ORDINANCE - OTHER":"statutory","FAILURE TO IDENTIFY":"statutory","UNLAWFUL CARRYING WEAPON":"statutory",
                                             "VIOL WATER SAFETY ACT":"statutory","APPLIC TO REVOKE PROBATION":"statutory",
                                             "VIOL STATE LAW - OTHER":"statutory","RESISTING ARREST OR SEARCH":"statutory","VIOL OF EMERG PROTECTIVE ORDER":"statutory",
                                             "VIOL OF PROTECTIVE ORDER":"statutory","FALSE REPORT TO PEACE OFFICER":"statutory","POSS OF FIREARM BY FELON":"statutory",
                                             "POSS OF PROHIBITED WEAPON":"statutory","FEDERAL VIOL/OTHER":"statutory","PAROLE VIOL":"statutory",
                                             "VIOL TEMP EX PARTE  ORDER":"statutory","IMMIGRATION HOLD/ARREST":"statutory","WEAPON VIOL - OTHER":"statutory"})

# %%
#converting specific offenses into crime types continued...

#financial group
crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({"FRAUD - OTHER":"financial","IDENTITY THEFT":"financial",
                                            "DEBIT CARD ABUSE":"financial","CRED CARD ABUSE - OTHER":"financial","FORGERY AND PASSING":"financial",
                                            "FORGERY - OTHER":"financial","IDENTITY THEFT-TAX RETURNS":"financial","CRED CARD ABUSE BY FORGERY":"financial",
                                             "COUNTERFEITING":"financial","ONLINE IMPERSONATION":"financial","FORGERY BY MAKING":"financial","THEFT BY CHECK":"financial",
                                             "GAMBLING":"financial","THEFT BY EMBEZZLEMENT":"financial","CRED CARD ABUSE - EXPIR-CANCEL":"financial",
                                            "FORGERY BY ALTERATION":"financial","FALSE STATEMENT -OBTAIN CREDIT":"financial","GAMBLING PROMOTION":"financial"})
#family/children group
crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({"RUNAWAY CHILD":"family/children","FAMILY DISTURBANCE/PARENTAL":"family/children",
                                            "CHILD CUSTODY INTERFERE":"family/children", "CHILD ENDANGERMENT- ABANDONMEN":"family/children","INJURY TO CHILD":"family/children",
                                             "INJURY TO CHILD (CARE/CUSTODY)":"family/children"})

#traffic
crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({"DWI":"traffic","DWI 2ND":"traffic",
                                            "DWI  .15 BAC OR ABOVE":"traffic","CUSTODY ARREST TRAFFIC WARR":"traffic","CRASH/FAIL STOP AND RENDER AID":"traffic",
                                            "DRIVING WHILE INTOX / FELONY":"traffic", "DWI - DRUG RECOGNITION EXPERT":"traffic","EVADING VEHICLE":"traffic",
                                            "UNAUTHORIZED USE VEH-EXPIRED":"traffic","VIOL CITY ORDINANCE - WRECKER":"traffic",
                                             "DWI - CHILD PASSENGER":"traffic","DUI - AGE 17 TO 20":"traffic"})      
#sex crimes group
crime_cons["Highest Offense Description"] = crime_cons["Highest Offense Description"].replace({"PUBLIC LEWDNESS":"sexual offense", "PROSTITUTION":"sexual offense",
                                            "DOC EXPOSURE":"sexual offense","POSS/PROMO CHILD PORNOGRAPHY":"sexual offense",
                                            "ONLINE SOLICITATION OF A MINOR":"sexual offense","PROMOTION OF PROSTITUTION":"sexual offense","INDECENT EXPOSURE":"sexual offense"})

# %%
crime_type_count = crime_cons["Highest Offense Description"].value_counts()
crime_type_count
# Out:
# property crime                    30801
# disturbances/mischief             24725
# assault                           11442
# drug/alcohol                       7830
# traffic                            6712
# financial                          5003
# statutory                          4145
# family/children                    3522
# sexual offense                      503
# DUMPING REFUSE NEAR HIGHWAY           9
# MISAPPLY FIDUCIARY PROP               9
# FRAUD DESTRUCTION OF A WRITING        9
# PROBATION VIOL                        9
# DISTRIB HARMFUL MATERIAL MINOR        9
# TRADEMARK COUNTERFEITING              9
# FORGERY OF IDENTIFICATION             8
# THEFT- APPROPRIATE STOLEN PROP        8
# DEL CONTROLLED SUB/OTHER              8
# INJ TO DISABLED  FAM/DATE VIOL        8
# DEL MARIJUANA                         7
# MAKING TOBACCO AVAIL TO MINOR         7
# TAKE WEAPON FRM POLICE OFFICER        7
# SIT AND LIE ORDINANCE VIOL            7
# ...

# %%
#drop where there are fewer than 10 instances of a crime
new_crime=crime_cons.groupby("Highest Offense Description").filter(lambda x: len(x) > 10)
new_crime
# Out:
#        Incident Number Highest Offense Description  Highest Offense Code  \
# 0         2.016520e+09                     traffic                  2100
# 1         2.016242e+10                     traffic                  2109
# 2         2.016298e+10                     traffic                  2100
# 3         2.016501e+10                   financial                  1199
# 4         2.016780e+09       disturbances/mischief                  3401
# 5         2.016129e+10       disturbances/mischief                  3401
# 6         2.016503e+10       disturbances/mischief                  1400
# 7         2.016102e+10       disturbances/mischief                  1400
# 8         2.016505e+10                   financial                  1108
# 9         2.016363e+10       disturbances/mischief                  2409
# 10        2.016501e+10                   financial                  1000
# 11        2.016334e+10       disturbances/mischief                  3401
# ...

# %%
#save to csv
new_crime.to_csv("2016 Austin crime data - clean.csv", index=False, header=True)

# %%
crime_type_count = new_crime["Highest Offense Description"].value_counts()
crime_type_count
# Out:
# property crime           30801
# disturbances/mischief    24725
# assault                  11442
# drug/alcohol              7830
# traffic                   6712
# financial                 5003
# statutory                 4145
# family/children           3522
# sexual offense             503
# Name: Highest Offense Description, dtype: int64
